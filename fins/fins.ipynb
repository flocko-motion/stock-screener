# %%
from terminal import *
# Out:
# FMP API key loaded successfully. Length: 32, First chars: ESo...
# FMP rate limit interval set to 0.1 seconds

# %%
f("AAPL MSFT GOOGL")
# Out:
#   ticker  weight
# 0   AAPL     1.0
# 1   MSFT     1.0
# 2  GOOGL     1.0

# %%
f("AAPL MSFT -> .mcap()")
# Out:
#   ticker  weight           mcap
# 0   AAPL     1.0  2996569554000
# 1   MSFT     1.0  3476050307200
