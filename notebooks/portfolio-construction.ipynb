# %% [markdown]
# # Building a first Portfolio Strategy

# %%
from fins.terminal import *
inbox = Get("fav/inbox.Basket")
inbox(Name() >> Description()).df()
# Out:
# Loaded Basket: /fav/inbox.Basket
# Plugin: Name(alias=None)
# Computing Name 88 items...
# Completed 88/88 in 0s (376.1/s)left
# Plugin: Description(alias=None)
# Computing Description 88 items...
# Completed 88/88 in 0s (5593.5/s) left
# Finished pipeline - final basket has 88 items
#    ticker  weight                              Name  \
# 0     ADP       1   Automatic Data Processing, Inc.
# 1      UI       1                     Ubiquiti Inc.
# 2      FN       2                          Fabrinet
# 3     UNH       1   UnitedHealth Group Incorporated
# 4     AJG       1         Arthur J. Gallagher & Co.
# ..    ...     ...                               ...
# 83    BAM       1  Brookfield Asset Management Ltd.
# 84   ARES       1       Ares Management Corporation
# 85    KKR       1                    KKR & Co. Inc.
# 86     BX       1                   Blackstone Inc.
# 87    JPM       1              JPMorgan Chase & Co.
#
#                                           Description
# ...

# %%
low_gl_corr = Basket(ADP, UNH, AJG, ORLY, RSG, MUSA, WRB, COST, COKE, AZO, RLI, PGR, SO, MGRC, RBC, CASY, FICO, WM, V, BMI, BLDR, HEI, BAH, ENSG, FI, ESLT, CTAS, AAON, NVO)
low_gl_corr.df()
Put(low_gl_corr, "fav/low_gl_corr")
# Out:
# [master e9e62b8] Update /fav/low_gl_corr.Basket
#  1 file changed, 157 insertions(+)
#  create mode 100644 fav/low_gl_corr.Basket.json
# Saved Basket: /fav/low_gl_corr.Basket

# %%
shopping_basket = Basket(AJG, UNH, ANET, MUSA, COKE, PGR, FICO, BLDR, HEI, BAH, FI, ERIE, AAON, CPRT)
shopping_basket_medical_dip = Basket(UNH, NVO)
shopping_basket_ultra_cagr = Basket(FICO, ARES, CTAS, TDG, MELI, NOW)
Put(shopping_basket, "fav/shopping_basket")
Put(shopping_basket_medical_dip, "fav/shopping_basket_medical_dip")
Put(shopping_basket_ultra_cagr, "fav/shopping_basket_ultra_cagr")
# Out:
# ...
# [master fb672a1] Update /fav/shopping_basket_medical_dip.Basket
#  1 file changed, 22 insertions(+)
#  create mode 100644 fav/shopping_basket_medical_dip.Basket.json
# Saved Basket: /fav/shopping_basket_medical_dip.Basket
# [master bb005cc] Update /fav/shopping_basket_ultra_cagr.Basket
#  1 file changed, 42 insertions(+)
#  create mode 100644 fav/shopping_basket_ultra_cagr.Basket.json
# Saved Basket: /fav/shopping_basket_ultra_cagr.Basket

# %%
cyclical = Basket(FN, ANET, TJX, AAPL, EXLS, PANW, APH, TXRH, TMUS, DRI, SMH, MPWR, SPGI, DSGX, CPRT, ODFL, MELI, NOW, AMZN, HD, KKR)
cyclical.df()
Put(cyclical, "fav/cyclical")
# Out:
# [master 0415207] Update /fav/cyclical.Basket
#  1 file changed, 117 insertions(+)
#  create mode 100644 fav/cyclical.Basket.json
# Saved Basket: /fav/cyclical.Basket

# %%
dip_watch = Basket(UI, FN, ABBV, RS, COKE, MPC, PAC, MGRC, GLNG, AMP, SPXC, LNG, ASR, VRTX, GATX, CQP, TSCO, MAR, VLO, CMC, TXRH, CAT, BANF, IBKR, OMAB, STLD, ERIE, ALNY, LECO, ESLT, TPL, AVAV, HALO, RJF, NFLX, AMZN, BN, BAM, BX, JPM)
dip_watch.df()
Put(dip_watch, "fav/dip_watch")
# Out:
# [master 0c0bf9a] Update /fav/dip_watch.Basket
#  1 file changed, 212 insertions(+)
#  create mode 100644 fav/dip_watch.Basket.json
# Saved Basket: /fav/dip_watch.Basket

# %%
research_required = Basket(HWKN)
Put(research_required, "fav/research_required")
# Out:
# [master c711764] Update /fav/research_required.Basket
#  1 file changed, 17 insertions(+)
#  create mode 100644 fav/research_required.Basket.json
# Saved Basket: /fav/research_required.Basket
